# %%
import pandas

# %%
x = pandas.read_excel('../original/immigrate.xlsx')

# %%
x
# Out:
#              统计日期  迁入地区 迁入来源地  迁入人口比例
# 0      2020-01-01  七台河市  哈尔滨市   28.25
# 1      2020-01-01  七台河市  佳木斯市   17.35
# 2      2020-01-01  七台河市   鸡西市   13.59
# 3      2020-01-01  七台河市  牡丹江市   10.60
# 4      2020-01-01  七台河市  双鸭山市    8.67
# ...           ...   ...   ...     ...
# 242863 2021-01-11   龙岩市   厦门市   26.07
# 242864 2021-01-11   龙岩市   漳州市   13.19
# 242865 2021-01-11   龙岩市   福州市   10.27
# 242866 2021-01-11   龙岩市   泉州市    9.96
# 242867 2021-01-11   龙岩市   三明市    7.92
#
# [242868 rows x 4 columns]

# %%
# !pwd
# Out:
# /Users/ncj/Documents/GitHub/schoolwork/information-visualization/data/json

# %%
x = x.rename(columns={"统计日期": "date", "迁入地区": "to", "迁入来源地": "from"})

# %%
cityes = x['from'].unique()

# %%
len(cityes)
# Out:
# 370

# %%
new_c = x['to'].unique()

# %%
len(new_c)
# Out:
# 390

# %%
# !ls ../original
# Out:
# NCP_ProvincialGDP.xlsx
# NCP_RegMedHosSta.xlsx
# emigrate.xlsx
# hospital.xlsx
# immigrate.xlsx
# 宏观经济景气指数表(月)133141128.zip
# 全国热门迁入迁出省份表(日)133101192.zip
# 国内主要经济指标环比数据表(月)133528113.zip
# 全国县级以上地名代码及经纬度.csv
# 全球及重点国家疫情主要指数数据-2020-6-22-7H-1 (1).xlsx

# %%
y = pandas.read_csv('../original/全国县级以上地名代码及经纬度.csv')

# %%
y
# Out:
#         行政代码          地名          东经         北纬
# 0     130426       河北省涉县  113.742914  36.598105
# 1     130930  河北省孟村回族自治县  117.159538  38.091265
# 2     140728      山西省平遥县  112.265493  37.148090
# 3     150424      内蒙古林西县  118.110216  43.771462
# 4     210202   辽宁省大连市中山区  121.677966  38.900436
# ...      ...         ...         ...        ...
# 3516  621201   甘肃省陇南市市辖区  104.934573  33.394480
# 3517  621202   甘肃省陇南市武都区  105.134553  33.293917
# 3518  621221       甘肃省成县  105.688289  33.747297
# 3519  621222       甘肃省文县  104.784206  32.947265
# 3520  621223      甘肃省宕昌县  104.452827  34.013489
#
# [3521 rows x 4 columns]

# %%
from tqdm import tqdm

# %%
cities
# Out:
# array(['哈尔滨市', '佳木斯市', '鸡西市', '牡丹江市', '双鸭山市', '海口市', '三亚市', '琼海市',
#        '陵水黎族自治县', '澄迈县', '乐东黎族自治县', '北京市', '万宁市', '福州市', '泉州市', '厦门市',
#        '南平市', '龙岩市', '文昌市', '江门市', '洛阳市', '郑州市', '运城市', '西安市', '渭南市',
#        '苏州市', '嘉兴市', '南通市', '杭州市', '无锡市', '南昌市', '景德镇市', '金华市', '鹰潭市',
#        '昌江黎族自治县', '儋州市', '深圳市', '广州市', '惠州市', '佛山市', '广西壮族自治区', '滨州市',
#        '潍坊市', '淄博市', '济南市', '青岛市', '宁夏回族自治区', '银川市', '吴忠市', '固原市',
#        '内蒙古自治区', '珠海市', '兰州市', '定西市', '甘南藏族自治州', '海东市', '西宁市', '太原市',
#        '晋中市', '吕梁市', '日照市', '枣庄市', '连云港市', '保山市', '昆明市', '大理白族自治州', '普洱市',
#        '东莞市', '沈阳市', '大连市', '本溪市', '鞍山市', '通化市', '温州市', '衢州市', '台州市',
#        '迪庆藏族自治州', '攀枝花市', '凉山彝族自治州', '呼和浩特市', '包头市', '大同市', '张家口市',
#        '鄂尔多斯市', '阿拉善盟', '巴彦淖尔市', '新疆维吾尔自治区', '昌吉回族自治州', '五家渠市', '吐鲁番市',
#        '伊犁哈萨克自治州', '东方市', '五指山市', '成都市', '眉山市', '宜宾市', '自贡市', '重庆市',
#        '黄冈市', '宜春市', '毕节市', '六盘水市', '肇庆市', '乌鲁木齐市', '塔城地区', '保亭黎族苗族自治县',
# ...

# %%
city_pos_dict = {}
for city in tqdm(cities):
#     city = city[:-1]
    flag = True
    for _, item in y.iterrows():
        if city in item['地名']:
            flag = False
            city_pos_dict[city] = [item['东经'], item['北纬']]
    if flag:
        print('Warning!!!')
        print(city)
for city in tqdm(new_c):
#     city = city[:-1]
    flag = True
    for _, item in y.iterrows():
        if city in item['地名']:
            flag = False
            city_pos_dict[city] = [item['东经'], item['北纬']]
    if flag:
        print('Warning!!!')
        print(city)
city_pos_dict
# Out:
#  15%|█▌        | 56/370 [00:17<01:38,  3.18it/s]
# Warning!!!
# 海东市
#  32%|███▏      | 120/370 [00:38<01:19,  3.16it/s]
# Warning!!!
# 可克达拉市
#  51%|█████     | 187/370 [00:59<00:56,  3.26it/s]
# Warning!!!
# 双河市
#  55%|█████▌    | 204/370 [01:04<00:49,  3.34it/s]
# Warning!!!
# 昆玉市
#  72%|███████▏  | 265/370 [01:22<00:31,  3.37it/s]
# Warning!!!
# 林芝市
#  73%|███████▎  | 270/370 [01:24<00:30,  3.33it/s]
# Warning!!!
# 铁门关市
#  80%|████████  | 296/370 [01:31<00:22,  3.29it/s]
# Warning!!!
# 山南市
#  86%|████████▋ | 320/370 [01:39<00:14,  3.36it/s]
# Warning!!!
# 昌都市
#  99%|█████████▉| 366/370 [01:52<00:01,  3.40it/s]
# Warning!!!
# 北屯市
# ...
#   1%|▏         | 5/390 [00:01<01:54,  3.37it/s]
# Warning!!!
# 三沙市
#  14%|█▎        | 53/390 [00:15<01:39,  3.40it/s]
# Warning!!!
# 北屯市
#  17%|█▋        | 65/390 [00:19<01:35,  3.40it/s]
# Warning!!!
# 双河市
#  17%|█▋        | 67/390 [00:19<01:34,  3.41it/s]
# Warning!!!
# 可克达拉市
#  32%|███▏      | 124/390 [00:36<01:19,  3.36it/s]
# Warning!!!
# 山南市
# ...

# %%
for _, item in y.iterrows():
    print(item)
    if city in item['地名']:
        print('lat ', item['东经'])
# Out:
# 行政代码     130426
# 地名        河北省涉县
# 东经      113.743
# 北纬      36.5981
# Name: 0, dtype: object
# 行政代码        130930
# 地名      河北省孟村回族自治县
# 东经          117.16
# 北纬         38.0913
# Name: 1, dtype: object
# 行政代码     140728
# 地名       山西省平遥县
# 东经      112.265
# 北纬      37.1481
# Name: 2, dtype: object
# 行政代码     150424
# 地名       内蒙古林西县
# 东经       118.11
# 北纬      43.7715
# Name: 3, dtype: object
# 行政代码       210202
# 地名      辽宁省大连市中山区
# 东经        121.678
# 北纬        38.9004
# Name: 4, dtype: object
# 行政代码        211401
# 地名      辽宁省葫芦岛市市辖区
# 东经         120.861
# 北纬          40.743
# Name: 5, dtype: object
# 行政代码     230182
# 地名      黑龙江省双城市
# 东经      126.189
# 北纬      45.4082
# Name: 6, dtype: object
# 行政代码         231003
# 地名      黑龙江省牡丹江市阳明区
# 东经          129.784
# 北纬           44.588
# Name: 7, dtype: object
# 行政代码       320501
# 地名      江苏省苏州市市辖区
# 东经         120.62
# 北纬         31.318
# Name: 8, dtype: object
# 行政代码       330205
# 地名      浙江省宁波市江北区
# 东经        121.493
# ...

# %%
'哈尔滨' in '黑龙江省哈尔滨市市辖区'
# Out:
# True

# %%
len(city_pos_dict)
# Out:
# 384

# %%
print(city_pos_dict)
# Out:
# {'哈尔滨市': [126.61077, 45.995674], '佳木斯市': [130.284735, 46.81378], '鸡西市': [130.566887, 45.205826], '牡丹江市': [129.584924, 44.491714], '双鸭山市': [131.564836, 46.529228], '海口市': [110.507269, 19.942909], '三亚市': [109.429348, 18.397248], '琼海市': [110.414359, 19.21483], '陵水黎族自治县': [109.94866100000002, 18.575985], '澄迈县': [109.99673600000001, 19.693135], '乐东黎族自治县': [109.062698, 18.658614], '北京市': [116.169735, 40.545156], '万宁市': [110.292505, 18.839886], '福州市': [119.314923, 26.221752000000002], '泉州市': [118.81901699999999, 25.173479], '厦门市': [118.280803, 24.675485000000002], '南平市': [118.254737, 26.590155], '龙岩市': [117.086322, 25.222206], '文昌市': [110.78090900000001, 19.750947], '江门市': [113.034751, 22.388215], '洛阳市': [112.46709299999999, 34.638791999999995], '郑州市': [112.777102, 34.759791], '运城市': [110.961931, 35.063677], '西安市': [108.874256, 34.066899], '渭南市': [109.564746, 34.55352], '苏州市': [120.63087800000001, 31.332306], '嘉兴市': [120.691907, 30.777679], '南通市': [120.823875, 32.071256], '杭州市': [119.998089
# ...

# %%
city_pos_dict['哈尔滨市']
# Out:
# [126.61077, 45.995674]

# %%
x
# Out:
#              date    to  from  迁入人口比例
# 0      2020-01-01  七台河市  哈尔滨市   28.25
# 1      2020-01-01  七台河市  佳木斯市   17.35
# 2      2020-01-01  七台河市   鸡西市   13.59
# 3      2020-01-01  七台河市  牡丹江市   10.60
# 4      2020-01-01  七台河市  双鸭山市    8.67
# ...           ...   ...   ...     ...
# 242863 2021-01-11   龙岩市   厦门市   26.07
# 242864 2021-01-11   龙岩市   漳州市   13.19
# 242865 2021-01-11   龙岩市   福州市   10.27
# 242866 2021-01-11   龙岩市   泉州市    9.96
# 242867 2021-01-11   龙岩市   三明市    7.92
#
# [242868 rows x 4 columns]

# %%
huge_json = []
for _, item in tqdm(x.iterrows()):
    if item['迁入人口比例'] > 20:
        try:
            lng1, lat1 = city_pos_dict[item['from']]
            lng2, lat2 = city_pos_dict[item['to']]
            temp = {
                'lng1': lng1,
                'lat1': lat1,
                'lng2': lng2,
                'lat2': lat2,
            }
            huge_json.append(temp)
        except:
            pass
# print(huge_json)
# Out:
# 242868it [00:22, 10586.45it/s]

# %%
import json
with open('huge_json2.json', 'w') as outfile:
    json.dump(huge_json[:1000], outfile)

# %%
len(huge_json)
# Out:
# 45319

# %%
print(huge_json[:1000])
# Out:
# [{'lng1': 126.61077, 'lat1': 45.995674, 'lng2': 131.475224, 'lat2': 45.883168}, {'lng1': 110.507269, 'lat1': 19.942909, 'lng2': 110.292505, 'lat2': 18.839886}, {'lng1': 119.314923, 'lat1': 26.221752000000002, 'lng2': 117.516896, 'lat2': 26.173967}, {'lng1': 112.46709299999999, 'lat1': 34.638791999999995, 'lng2': 111.281295, 'lat2': 34.771778000000005}, {'lng1': 120.63087800000001, 'lat1': 31.332306, 'lng2': 121.56064199999999, 'lat2': 30.915121999999997}, {'lng1': 110.507269, 'lat1': 19.942909, 'lng2': 108.85101, 'lat2': 18.998161}, {'lng1': 109.429348, 'lat1': 18.397248, 'lng2': 108.85101, 'lat2': 18.998161}, {'lng1': 114.27848300000001, 'lat1': 22.606981, 'lng2': 113.763434, 'lat2': 23.043024}, {'lng1': 117.98121100000002, 'lat1': 37.424890999999995, 'lng2': 118.62001200000002, 'lat2': 37.9695}, {'lng1': 106.15548100000001, 'lat1': 37.321323, 'lng2': 105.111278, 'lat2': 37.360639}, {'lng1': 106.24265, 'lat1': 38.478590999999994, 'lng2': 105.111278, 'lat2': 37.360639}, {'lng1': 106.
# ...

# %%
# !ls ../../src/components/HospitalNum.json
# Out:
# ../../src/components/HospitalNum.json

# %%
hospitals = pandas.read_json('../../src/components/HospitalNum.json')

# %%
hospitals
# Out:
#          name  value
# 0          北京    106
# 1          天津     47
# 2         石家庄     55
# 3          唐山     49
# 4         秦皇岛     25
# ..        ...    ...
# 357  伊犁哈萨克自治州     29
# 358      塔城地区      9
# 359     阿勒泰地区     10
# 360       石河子      2
# 361        北屯      1
#
# [362 rows x 2 columns]

# %%
hospital_json = []
for _, city in tqdm(hospitals.iterrows()):
    for _, item in y.iterrows():
        if city['name'] in item['地名']:
            lng, lat = item['东经'], item['北纬']
            temp = {
                'lng': lng,
                'lat': lat,
                'value': city['value'],
                'name': city['name']
            }
            hospital_json.append(temp)
            break
hospital_json
# Out:
# 362it [01:03,  5.74it/s]
# [{'lng': 116.395645, 'lat': 39.929986, 'value': 106, 'name': '北京'},
#  {'lng': 117.21081299999999, 'lat': 39.14393, 'value': 47, 'name': '天津'},
#  {'lng': 114.52208200000001, 'lat': 38.048958, 'value': 55, 'name': '石家庄'},
#  {'lng': 118.183451, 'lat': 39.650531, 'value': 49, 'name': '唐山'},
#  {'lng': 119.604368, 'lat': 39.945462, 'value': 25, 'name': '秦皇岛'},
#  {'lng': 114.482694, 'lat': 36.609308, 'value': 31, 'name': '邯郸'},
#  {'lng': 114.52048700000002, 'lat': 37.069531, 'value': 48, 'name': '邢台'},
#  {'lng': 115.49481000000002,
#   'lat': 38.886565000000004,
#   'value': 55,
#   'name': '保定'},
#  {'lng': 114.893782, 'lat': 40.811188, 'value': 45, 'name': '张家口'},
#  {'lng': 117.93382199999999, 'lat': 40.992521, 'value': 23, 'name': '承德'},
#  {'lng': 116.86380600000001, 'lat': 38.297615, 'value': 5, 'name': '沧州'},
#  {'lng': 116.703602, 'lat': 39.518611, 'value': 26, 'name': '廊坊'},
# ...

# %%
import json
with open('hospital_json.json', 'w') as outfile:
    json.dump(hospital_json, outfile)
